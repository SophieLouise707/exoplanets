# %% [markdown]
# Notes:
# - [Chiang and Laughlin (2013)](https://arxiv.org/pdf/1211.1673) used the Kepler sample to calculate the best-fit minimum mass extrasolar nebula (MMEN), and compare it to the Minimum Mass Solar Nebula (MMSN) from [Hayashi (1981)]
# - majority of main-sequence Sun-like stars harbor planets with R > 2R⊕ and P < 100 days
# - We compute from scratch a “minimum-mass extrasolar nebula” (MMEN) using the abundance of data from the Kepler mission (§2)
#
# **Used subset of Kepler sample, chose targets with the following characteristics:**
# - solar mass similar to sun's mass(0.8-1.2M_*)
# - solar radius similar to sun's radius (.9 = 1.2R_*)
# - similar metalicity to sun [-0.5 to 0.5 dex]
# - 5000-6000T_eff
# - P < 100 days

# %%
import pandas as pd 
import matplotlib.pyplot as plt
df = pd.read_csv("C:/Users/jacob/Downloads/PS_2026.04.03_14.34.19.csv", skiprows = 37, usecols = ['pl_name', 'pl_orbper', 'pl_orbpererr1', 'pl_orbpererr2', 'pl_masse', 'pl_masseerr1', 'pl_masseerr2'])
df = df[df['pl_masse'].notna()]

earth_mass = df['pl_masse']
period = df['pl_orbper']
plt.scatter(period, earth_mass)
plt.xlabel('Period [days]')
plt.ylabel('Mass [M_earth]')
# Out:
# Text(0, 0.5, 'Mass [M_earth]')
